# %% [markdown]
# <a href="https://colab.research.google.com/github/Jed-Miller/deep-learning-challenge/blob/main/charity_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_val_count = application_df['APPLICATION_TYPE'].value_counts()
app_val_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_val_count[app_val_count<500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_val_count = application_df['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
print (class_val_count[class_val_count > 1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_val_count[class_val_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)
application_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATUS                        34299 non-null  int64
#  1   ASK_AMT                       34299 non-null  int64
#  2   IS_SUCCESSFUL                 34299 non-null  int64
#  3   APPLICATION_TYPE_Other        34299 non-null  uint8
#  4   APPLICATION_TYPE_T10          34299 non-null  uint8
#  5   APPLICATION_TYPE_T19          34299 non-null  uint8
#  6   APPLICATION_TYPE_T3           34299 non-null  uint8
#  7   APPLICATION_TYPE_T4           34299 non-null  uint8
#  8   APPLICATION_TYPE_T5           34299 non-null  uint8
#  9   APPLICATION_TYPE_T6           34299 non-null  uint8
#  10  APPLICATION_TYPE_T7           34299 non-null  uint8
#  11  APPLICATION_TYPE_T8           34299 non-null  uint8
#  12  AFFILIATION_CompanySponsored  34299 non-null  uint8
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_numeric.drop(columns=['IS_SUCCESSFUL'])
y = application_numeric['IS_SUCCESSFUL']


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer

nn_model_1 = tf.keras.models.Sequential()

# First hidden layer
nn_model_1.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=43))

# Second hidden layer
nn_model_1.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn_model_1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
train_model = nn_model_1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5711 - accuracy: 0.7221
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7309
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5529 - accuracy: 0.7308
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7332
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7326
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7339
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7343
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5475 - accuracy: 0.7339
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7352
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5584 - accuracy: 0.7215 - 462ms/epoch - 2ms/step
# Loss: 0.5584197044372559, Accuracy: 0.7215160131454468

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn_model_1.save('model1.h5')

# %%
# Define the second model - deep neural net, i.e., the number of input features and hidden nodes for each layer

nn_model_2 = tf.keras.models.Sequential()

# First hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=90, activation='relu', input_dim=43))

# Second hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Third hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=20, activation='relu'))

# Output layer
nn_model_2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 90)                3960
#
#  dense_8 (Dense)             (None, 30)                2730
#
#  dense_9 (Dense)             (None, 20)                620
#
#  dense_10 (Dense)            (None, 1)                 21
#
# ...
# Total params: 7,331
# Trainable params: 7,331
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the second model
nn_model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the second model
train_model_2 = nn_model_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5700 - accuracy: 0.7211
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5544 - accuracy: 0.7306
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5519 - accuracy: 0.7319
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5503 - accuracy: 0.7322
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5495 - accuracy: 0.7328
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7345
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7346
# Epoch 8/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5472 - accuracy: 0.7348
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5464 - accuracy: 0.7362
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5560 - accuracy: 0.7276 - 442ms/epoch - 2ms/step
# Loss: 0.5559623837471008, Accuracy: 0.727580189704895

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn_model_2.save('model2.h5')

# %%
# Define the third model - deep neural net, i.e., the number of input features and hidden nodes for each layer

nn_model_3 = tf.keras.models.Sequential()

# First hidden layer
nn_model_3.add(tf.keras.layers.Dense(units=70, activation='relu', input_dim=43))

# Second hidden layer
nn_model_3.add(tf.keras.layers.Dense(units=70, activation='relu'))

# Output layer
nn_model_3.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 70)                3080
#
#  dense_12 (Dense)            (None, 70)                4970
#
#  dense_13 (Dense)            (None, 1)                 71
#
# ...
# Total params: 8,121
# Trainable params: 8,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the third model
nn_model_3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the third model
train_model_3 = nn_model_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5736 - accuracy: 0.7200
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5566 - accuracy: 0.7297
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7315
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5515 - accuracy: 0.7328
# Epoch 5/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5494 - accuracy: 0.7322
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5485 - accuracy: 0.7333
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7333
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7317
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7342
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5602 - accuracy: 0.7264 - 544ms/epoch - 2ms/step
# Loss: 0.5602385997772217, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn_model_3.save('model3.h5')

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_op_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_op_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=120,
        step=10), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 4)):
        nn_op_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=40,
            step=10),
            activation=activation))

    nn_op_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_op_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_op_model

# %%
# !pip install keras_tuner

# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=5,
    hyperband_iterations=2)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=5,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 20 Complete [00h 00m 15s]
# val_accuracy: 0.7261807322502136
#
# Best val_accuracy So Far: 0.7264139652252197
# Total elapsed time: 00h 03m 49s

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 51,
#  'num_layers': 2,
#  'units_0': 21,
#  'tuner/epochs': 5,
#  'tuner/initial_epoch': 2,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'units_1': 1,
#  'tuner/trial_id': '0000',
#  'units_2': 31,
#  'units_3': 11}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5626 - accuracy: 0.7264 - 570ms/epoch - 2ms/step
# Loss: 0.5625960826873779, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn_model_3.save('best_model.h5')

# %%
#Read best model
loaded_model = tf.keras.models.load_model("best_model.h5")
loaded_model.get_config()
# Out:
# {'name': 'sequential_3',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 43),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'dense_11_input'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_11',
#     'trainable': True,
#     'dtype': 'float32',
#     'batch_input_shape': (None, 43),
#     'units': 70,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_12',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 70,
#     'activation': 'relu',
#     'use_bias': True,
# ...
